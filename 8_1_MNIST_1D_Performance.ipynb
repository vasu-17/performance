# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(nn.Linear(D_i, D_k), nn.ReLU(), nn.Linear(D_k, D_k), nn.ReLU(), nn.Linear(D_k, D_o));


def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform(layer_in.weight)
        layer_in.bias.data.fill_(0.0)
      


# Call the function you just defined
model.apply(weights_init)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_28464\426614360.py:13: FutureWarning: `nn.init.kaiming_uniform` is now deprecated in favor of `nn.init.kaiming_uniform_`.
#   nn.init.kaiming_uniform(layer_in.weight)
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_28464\426614360.py:13: FutureWarning: `nn.init.kaiming_uniform` is now deprecated in favor of `nn.init.kaiming_uniform_`.
#   nn.init.kaiming_uniform(layer_in.weight)
# Epoch     0, train loss 1.607919, train error 62.65,  test loss 1.687379, test error 68.20
# Epoch     1, train loss 1.357429, train error 51.10,  test loss 1.501838, test error 59.90
# Epoch     2, train loss 1.181890, train error 44.67,  test loss 1.366264, test error 54.50
# Epoch     3, train loss 1.018500, train error 36.95,  test loss 1.274564, test error 50.50
# Epoch     4, train loss 0.903257, train error 32.88,  test loss 1.218082, test error 46.30
# Epoch     5, train loss 0.804789, train error 28.60,  test loss 1.199950, test error 47.10
# Epoch     6, train loss 0.705471, train error 22.88,  test loss 1.140228, test error 42.20
# Epoch     7, train loss 0.677297, train error 23.20,  test loss 1.194740, test error 44.90
# Epoch     8, train loss 0.577059, train error 20.28,  test loss 1.156368, test error 41.10
# Epoch     9, train loss 0.505913, train error 17.43,  test loss 1.133584, test error 40.80
# Epoch    10, train loss 0.423042, train error 13.22,  test loss 1.082099, test error 38.50
# Epoch    11, train loss 0.380424, train error 11.30,  test loss 1.081732, test error 37.30
# Epoch    12, train loss 0.376516, train error 11.70,  test loss 1.113471, test error 37.70
# Epoch    13, train loss 0.309731, train error 7.65,  test loss 1.101591, test error 38.30
# Epoch    14, train loss 0.283263, train error 6.15,  test loss 1.132645, test error 38.80
# Epoch    15, train loss 0.258274, train error 5.75,  test loss 1.131414, test error 38.50
# Epoch    16, train loss 0.234088, train error 4.82,  test loss 1.139881, test error 38.10
# Epoch    17, train loss 0.215301, train error 4.50,  test loss 1.163019, test error 38.70
# Epoch    18, train loss 0.195303, train error 3.43,  test loss 1.192724, test error 38.70
# Epoch    19, train loss 0.178186, train error 2.82,  test loss 1.224569, test error 38.10
# Epoch    20, train loss 0.151665, train error 1.53,  test loss 1.197867, test error 37.80
# Epoch    21, train loss 0.141632, train error 1.20,  test loss 1.221551, test error 38.00
# Epoch    22, train loss 0.134505, train error 1.03,  test loss 1.221371, test error 36.60
# Epoch    23, train loss 0.128299, train error 1.05,  test loss 1.240669, test error 38.20
# Epoch    24, train loss 0.122843, train error 0.95,  test loss 1.248498, test error 37.60
# Epoch    25, train loss 0.116346, train error 0.75,  test loss 1.266908, test error 37.00
# Epoch    26, train loss 0.108385, train error 0.60,  test loss 1.267586, test error 37.10
# Epoch    27, train loss 0.102387, train error 0.40,  test loss 1.278909, test error 37.00
# Epoch    28, train loss 0.098063, train error 0.35,  test loss 1.287724, test error 37.60
# Epoch    29, train loss 0.095101, train error 0.28,  test loss 1.311307, test error 37.10
# Epoch    30, train loss 0.088365, train error 0.10,  test loss 1.312546, test error 36.50
# Epoch    31, train loss 0.085739, train error 0.07,  test loss 1.321257, test error 36.60
# Epoch    32, train loss 0.083840, train error 0.07,  test loss 1.323570, test error 37.30
# Epoch    33, train loss 0.082347, train error 0.05,  test loss 1.328468, test error 36.90
# Epoch    34, train loss 0.080125, train error 0.07,  test loss 1.337605, test error 37.00
# Epoch    35, train loss 0.078175, train error 0.03,  test loss 1.337338, test error 37.20
# Epoch    36, train loss 0.076286, train error 0.03,  test loss 1.346982, test error 36.70
# Epoch    37, train loss 0.074523, train error 0.03,  test loss 1.357481, test error 37.10
# Epoch    38, train loss 0.072886, train error 0.03,  test loss 1.360782, test error 36.80
# Epoch    39, train loss 0.071398, train error 0.03,  test loss 1.363713, test error 36.50
# Epoch    40, train loss 0.070051, train error 0.03,  test loss 1.366962, test error 37.30
# Epoch    41, train loss 0.069419, train error 0.03,  test loss 1.369834, test error 37.00
# Epoch    42, train loss 0.068551, train error 0.03,  test loss 1.371910, test error 37.20
# Epoch    43, train loss 0.067947, train error 0.03,  test loss 1.376617, test error 36.80
# Epoch    44, train loss 0.067280, train error 0.03,  test loss 1.377422, test error 37.20
# Epoch    45, train loss 0.066356, train error 0.03,  test loss 1.380122, test error 37.00
# Epoch    46, train loss 0.065674, train error 0.03,  test loss 1.384026, test error 37.30
# Epoch    47, train loss 0.064937, train error 0.03,  test loss 1.385569, test error 36.90
# Epoch    48, train loss 0.064326, train error 0.03,  test loss 1.386459, test error 37.30
# Epoch    49, train loss 0.063935, train error 0.03,  test loss 1.391562, test error 37.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
#
# Changing/optimizing the hyperparameters can definetly improve the understanding of the model but it can sometimes lead to overfitting. A better idea would be to use a validation set to optimize the parameters and k-fold cross validation.
